# %% [markdown]
# ## 🚨 Warning 🚨
#
# This Notebook builds on 1_Introduction.
#
# You have to run that Notebook (if you didn't already) and mount your Google Drive to this Notebook via
# ```python
# from google.colab import drive
# drive.mount('/content/drive')
# ```
# then you are ready to go!

# %% [markdown]
# # Data Exploration
#
# **"Before running actual analyses, the data should be looked at with a critical eye!" - Prof. Brainy**

# %% [markdown]
# ![critical_brain.png](data:image/png;base64,...)

# %% [markdown]
# ## 1 `glob`
#
# The build-in Python module `glob` allows you to **find all the pathnames matching a specified pattern**
#
# ```python
# import glob
#
# # In the folder '/path/to/data' are two files: 'dog.png' and 'cat.png'
# png_files = glob.glob('/path/to/data/*.png')  # returns ['/path/to/data/dog.png', '/path/to/data/cat.png']
# ```
#
# **Task 1.1:** Print all filepaths in "drive/MyDrive/openneuro/ds000001/sub-01/anat".

# %% [markdown]
# **Task 1.2:** Print all filepaths in "drive/MyDrive/openneuro/ds000001/sub-01/func".

# %% [markdown]
# **Task 1.3:** Print all filepaths from Task 1.1 + 1.2 while only using `glob.glob` once.

# %% [markdown]
# **Task 1.4:** Print all folder- and filepaths inside of the folder ds000001.

# %% [markdown]
# ## 2 `Path`
#
# The build-in Python module `pathlib` provides a convenient way to handle file paths
#
# ```python
# from pathlib import Path
#
# folder_path = Path('path/to/my/data')
# file_path = Path('image_0.png')
# full_path = folder_path / file_path
# ```
#
# Additionally, `Path` can be used check if files exist
# ```python
# full_path = Path('path/to/my/data/image_0.png')
# full_path.is_file()  # returns True or False
# ```
# create folders
# ```python
# Path('existing_folder/new_folder').mkdir()
# ```
# or extract the filename and filestem out of a filepath
# ```python
# full_path = Path('path/to/my/data/image_0.png')
# full_path.name  # returns image_0.png
# full_path.stem  # returns image_0
# ```
# **Task 2.1:** Print all folder- and filenames from Task 1.4.

# %% [markdown]
# **Task 2.2:** Given all folder- and filepaths from Task 1.4, print only the filepaths.

# %% [markdown]
# **Task 2.3:** Create a new folder "new" and in that folder a subfolder "folder"

# %% [markdown]
# **Task 2.4:** Create a new folder "new" and in that folder a subfolder "folder" while using .mkdir() only once.

# %% [markdown]
# # Exercise
#
# 1. Load the "participants.tsv" as a DataFrame with "participant_id" as index

# %% [markdown]
# 2. Create a pandas Series of absolute filepath of the "...T1w.nii.gz" for each participant

# %% [markdown]
# 3. Check if there exists "sub-XY/anat/sub-XY_T1w.nii.gz" for each participant_id XY and create a pandas Series of these True/False values

# %% [markdown]
# 4. Add both Series as new columns to the DataFrame

# %% [markdown]
# 5. Save the DataFrame to "drive/MyDrive/openneuro/dataframe.csv"
