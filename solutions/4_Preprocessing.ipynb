# %% [markdown]
# # Preprocessing

# %% [markdown]
# For traditional statistical analysis there exist established preprocessing pipelines such as
# - [FreeSurfer](https://surfer.nmr.mgh.harvard.edu/)
# - [CAT12](https://neuro-jena.github.io/cat/)
# - [SPM](https://www.fil.ion.ucl.ac.uk/spm/)
#
# which align Niftis using a bunch of operations (see image) enabling simple regression analysis for specific voxel positions.

# %% [markdown]
# <p>
# <img src="https://neuro-jena.github.io/cat12-help/images/cat_processing_steps.png" width=600/>
# <figcaption>Taken from <a href="https://neuro-jena.github.io/cat12-help/images/cat_processing_steps.png">https://neuro-jena.github.io/cat12-help/images/cat_processing_steps.png</a></figcaption>
# </p>

# %% [markdown]
# Luckily, Neural Nets are more advanced than simple regression methods and can perform high precision prediciton without rigorous alignment.
#
# Therefore, (and for brevity) we only apply minimal preprocessing.

# %% [markdown]
# ## 1. Brain Extraction
# As we are only interested in the brain of the participants, we first have to set all voxels which are not inside the brain to 0.
#
# Luckily, there exist a neural net based tool called [deepbet](https://github.com/wwu-mmll/deepbet) which enables brain extraction via:
#
# ```python
# from deepbet import run_bet
#
# input_paths = ['path/to/sub_1/t1.nii.gz', 'path/to/sub_2/t1.nii.gz']
# mask_paths = ['path/to/sub_1/mask.nii.gz', 'path/to/sub_2/mask.nii.gz']
# brain_paths = ['path/to/sub_1/brain.nii.gz', 'path/to/sub_2/brain.nii.gz']
#
# run_bet(input_paths, brain_paths)
# ```

# %% [markdown]
# ________________
# ### Enable GPU on Colab 🔥
#
# Like most neural net based tools deepbet can be run on GPU and thereby realize a speedup compared to normal CPU execution 💨
#
# Thankfully, Colab allows you to use a GPU for free 🍀
#
# To enable GPU you simply click on
# - *Runtime*
# - *Change runtime type*
# - *T4 GPU*
# ________________

# %% [markdown]
# # Exercise 1

# %% [markdown]
# ## 🚨 Warning 🚨
#
# This Notebook builds on 1_Introduction and the Exercise of 2_Data_Exploration.
#
# You have to run that Notebook (if you didn't already) and mount your Google Drive to this Notebook via
# ```python
# from google.colab import drive
# drive.mount('/content/drive')
# ```
# then you are ready to go!

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# 1. Install `deepbet`

# %%
# !pip install deepbet
# Out:
# Collecting deepbet
#   Downloading deepbet-0.0.2-py3-none-any.whl (10.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.2/10.2 MB 27.7 MB/s eta 0:00:00
# Collecting connected-components-3d (from deepbet)
#   Downloading connected_components_3d-3.12.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 99.3 MB/s eta 0:00:00
# Collecting fill_voids (from deepbet)
#   Downloading fill_voids-2.0.6-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 84.8 MB/s eta 0:00:00
# Requirement already satisfied: nibabel in /usr/local/lib/python3.10/dist-packages (from deepbet) (4.0.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from deepbet) (1.5.3)
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (from deepbet) (2.1.0+cu121)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from deepbet) (4.66.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from connected-components-3d->deepbet) (1.25.2)
# Collecting fastremap (from fill_voids->deepbet)
#   Downloading fastremap-1.14.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (6.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.0/6.0 MB 56.6 MB/s eta 0:00:00
# Requirement already satisfied: packaging>=17.0 in /usr/local/lib/python3.10/dist-packages (from nibabel->deepbet) (23.2)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from nibabel->deepbet) (67.7.2)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->deepbet) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->deepbet) (2023.4)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch->deepbet) (3.13.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch->deepbet) (4.9.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch->deepbet) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch->deepbet) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch->deepbet) (3.1.3)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch->deepbet) (2023.6.0)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch->deepbet) (2.1.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas->deepbet) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch->deepbet) (2.1.5)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch->deepbet) (1.3.0)
# Installing collected packages: fastremap, connected-components-3d, fill_voids, deepbet
# Successfully installed connected-components-3d-3.12.4 deepbet-0.0.2 fastremap-1.14.1 fill_voids-2.0.6

# %% [markdown]
# 2. Load the DataFrame you saved at the end of the exercise in 2_Data_Exploration

# %%
import pandas as pd
PATH = '/content/drive/MyDrive/openneuro'

df = pd.read_csv(f'{PATH}/dataframe.csv')

# %% [markdown]
# 3. Create two new columns called `brain_filepath` and `mask_filepath` containing the output filepaths needed for the `run_bet` function
#
# The output filepaths should be in the following pattern
# - the `t1w_filepath` "...ds000001/sub-XY/anat/sub-XY_T1w.nii.gz"
#
# results in
#
# - the `brain_filepath`: "...ds000001/derivatives/sub-XY/anat/sub-XY_deepbet-brain_T1w.nii.gz"
# - the `mask_filepath`: "...ds000001/derivatives/sub-XY/anat/sub-XY_deepbet-mask_T1w.nii.gz"

# %%
df['brain_filepath'] = df.t1w_filepath.str.replace('ds000001', 'ds000001/derivatives')
df['brain_filepath'] = df.brain_filepath.str.replace('T1w', 'deepbet-brain_T1w')
df['mask_filepath'] = df.t1w_filepath.str.replace('ds000001', 'ds000001/derivatives')
df['mask_filepath'] = df.mask_filepath.str.replace('T1w', 'deepbet-mask_T1w')
df
# Out:
#    participant_id sex  age                                       t1w_filepath  \
# 0          sub-01   F   26  /content/drive/MyDrive/openneuro/ds000001/sub-...
# 1          sub-02   M   24  /content/drive/MyDrive/openneuro/ds000001/sub-...
# 2          sub-03   F   27  /content/drive/MyDrive/openneuro/ds000001/sub-...
# 3          sub-04   F   20  /content/drive/MyDrive/openneuro/ds000001/sub-...
# 4          sub-05  M,   22  /content/drive/MyDrive/openneuro/ds000001/sub-...
# 5          sub-06   F   26  /content/drive/MyDrive/openneuro/ds000001/sub-...
# 6          sub-07   M   24  /content/drive/MyDrive/openneuro/ds000001/sub-...
# 7          sub-08   M   21  /content/drive/MyDrive/openneuro/ds000001/sub-...
# 8          sub-09   M   26  /content/drive/MyDrive/openneuro/ds000001/sub-...
# 9          sub-10   F   21  /content/drive/MyDrive/openneuro/ds000001/sub-...
# 10         sub-11   F   24  /content/drive/MyDrive/openneuro/ds000001/sub-...
# 11         sub-12   F   22  /content/drive/MyDrive/openneuro/ds000001/sub-...
# 12         sub-13   F   21  /content/drive/MyDrive/openneuro/ds000001/sub-...
# 13         sub-14   F   30  /content/drive/MyDrive/openneuro/ds000001/sub-...
# 14         sub-15   F   24  /content/drive/MyDrive/openneuro/ds000001/sub-...
# 15         sub-16   M   19  /content/drive/MyDrive/openneuro/ds000001/sub-...
#
#     t1w_file_exists                                     brain_filepath  \
# 0              True  /content/drive/MyDrive/openneuro/ds000001/deri...
# 1              True  /content/drive/MyDrive/openneuro/ds000001/deri...
# 2              True  /content/drive/MyDrive/openneuro/ds000001/deri...
# 3              True  /content/drive/MyDrive/openneuro/ds000001/deri...
# 4              True  /content/drive/MyDrive/openneuro/ds000001/deri...
# 5              True  /content/drive/MyDrive/openneuro/ds000001/deri...
# 6              True  /content/drive/MyDrive/openneuro/ds000001/deri...
# 7              True  /content/drive/MyDrive/openneuro/ds000001/deri...
# 8              True  /content/drive/MyDrive/openneuro/ds000001/deri...
# 9              True  /content/drive/MyDrive/openneuro/ds000001/deri...
# 10             True  /content/drive/MyDrive/openneuro/ds000001/deri...
# 11             True  /content/drive/MyDrive/openneuro/ds000001/deri...
# 12             True  /content/drive/MyDrive/openneuro/ds000001/deri...
# 13             True  /content/drive/MyDrive/openneuro/ds000001/deri...
# 14             True  /content/drive/MyDrive/openneuro/ds000001/deri...
# 15             True  /content/drive/MyDrive/openneuro/ds000001/deri...
#
#                                         mask_filepath
# 0   /content/drive/MyDrive/openneuro/ds000001/deri...
# 1   /content/drive/MyDrive/openneuro/ds000001/deri...
# 2   /content/drive/MyDrive/openneuro/ds000001/deri...
# 3   /content/drive/MyDrive/openneuro/ds000001/deri...
# 4   /content/drive/MyDrive/openneuro/ds000001/deri...
# 5   /content/drive/MyDrive/openneuro/ds000001/deri...
# 6   /content/drive/MyDrive/openneuro/ds000001/deri...
# 7   /content/drive/MyDrive/openneuro/ds000001/deri...
# 8   /content/drive/MyDrive/openneuro/ds000001/deri...
# 9   /content/drive/MyDrive/openneuro/ds000001/deri...
# 10  /content/drive/MyDrive/openneuro/ds000001/deri...
# 11  /content/drive/MyDrive/openneuro/ds000001/deri...
# 12  /content/drive/MyDrive/openneuro/ds000001/deri...
# 13  /content/drive/MyDrive/openneuro/ds000001/deri...
# 14  /content/drive/MyDrive/openneuro/ds000001/deri...
# 15  /content/drive/MyDrive/openneuro/ds000001/deri...

# %% [markdown]
# 4. Save the DataFrame to "drive/MyDrive/openneuro/dataframe_after_deepbet.csv"

# %%
df.to_csv(f'{PATH}/dataframe_after_deepbet.csv', index=False)

# %% [markdown]
# 5. Create the needed "...ds000001/derivatives/sub-XY/anat/" directories using `Path`

# %%
from pathlib import Path

for fpath in df.brain_filepath:
  Path(fpath).parent.mkdir(parents=True, exist_ok=True)

# %% [markdown]
# 6. Run brain extraction via `run_bet` using the filepath columns from 3.

# %%
from deepbet import run_bet

run_bet(df.t1w_filepath, df.brain_filepath, df.mask_filepath)
# Out:
# 100%|██████████| 16/16 [00:21<00:00,  1.37s/it]

# %% [markdown]
# ## 2. Intensity Normalization
#
# Image Normalization is a non-trivial preprocessing step and there is no established best way to apply it ([here](https://github.com/jcreinhold/intensity-normalization) is a detailed resource).
#
# Again for brevity, we will only discuss two typically used normalization techniques which are also used for non-image data.

# %% [markdown]
# ### 2.1 Min-max Normalization
#
# Min-Max normalization scales the values of an array to a range between 0 and 1
#
# ```python
# import numpy as np
#
# x = np.array([1, 2, 3, 4, 5])
# x_min = x.min()
# x_max = x.max()
# x_normalized = (x - x_min) / (x_max - x_min)
# ```
#
# **Task 2.1:** What are Pros and Cons of Min-Max normalization?

# %% [markdown]
# Pros
# - fixed value range
# - no loss of information
#
# Cons
#
# - sensitive to outlier min./max. values

# %% [markdown]
# ### 2.2 Z-score Normalization
#
# Z-score normalization, also known as standardization, scales the values of an array to have a mean of 0 and a standard deviation of 1
#
# ```python
# import numpy as np
#
# x = np.array([1, 2, 3, 4, 5])
# mu = x.mean()
# std = x.std()
# x_normalized = (x - mu) / std
# ```
#
# **Task 2.2:** What are Pros and Cons of Z-score normalization?

# %% [markdown]
# Pros
#
# - insensitive to outlier values
# - no loss of information
#
# Cons
#
# - value range not fixed

# %% [markdown]
# # Exercise 2
# 1. Load the DataFrame from Exercise 1

# %%
import pandas as pd

df = pd.read_csv('drive/MyDrive/openneuro/dataframe_after_deepbet.csv')

# %% [markdown]
# 2. Add two columns `brain_minmax_filepath` and `brain_zscore_filepath` containing the output filepaths. These should be in the same folder as `df.brain_filepath` and called "sub-XY_deepbet-brain-minmax_T1w.nii.gz" and "sub-XY_deepbet-brain-zscore_T1w.nii.gz", respectively.

# %%
df['minmax_filepath'] = df.brain_filepath.str.replace('deepbet-brain', 'deepbet-minmax')
df['zscore_filepath'] = df.brain_filepath.str.replace('deepbet-brain', 'deepbet-zscore')
df
# Out:
#    participant_id sex  age                                       t1w_filepath  \
# 0          sub-01   F   26  /content/drive/MyDrive/openneuro/ds000001/sub-...
# 1          sub-02   M   24  /content/drive/MyDrive/openneuro/ds000001/sub-...
# 2          sub-03   F   27  /content/drive/MyDrive/openneuro/ds000001/sub-...
# 3          sub-04   F   20  /content/drive/MyDrive/openneuro/ds000001/sub-...
# 4          sub-05  M,   22  /content/drive/MyDrive/openneuro/ds000001/sub-...
# 5          sub-06   F   26  /content/drive/MyDrive/openneuro/ds000001/sub-...
# 6          sub-07   M   24  /content/drive/MyDrive/openneuro/ds000001/sub-...
# 7          sub-08   M   21  /content/drive/MyDrive/openneuro/ds000001/sub-...
# 8          sub-09   M   26  /content/drive/MyDrive/openneuro/ds000001/sub-...
# 9          sub-10   F   21  /content/drive/MyDrive/openneuro/ds000001/sub-...
# 10         sub-11   F   24  /content/drive/MyDrive/openneuro/ds000001/sub-...
# 11         sub-12   F   22  /content/drive/MyDrive/openneuro/ds000001/sub-...
# 12         sub-13   F   21  /content/drive/MyDrive/openneuro/ds000001/sub-...
# 13         sub-14   F   30  /content/drive/MyDrive/openneuro/ds000001/sub-...
# 14         sub-15   F   24  /content/drive/MyDrive/openneuro/ds000001/sub-...
# 15         sub-16   M   19  /content/drive/MyDrive/openneuro/ds000001/sub-...
#
#     t1w_file_exists                                     brain_filepath  \
# 0              True  /content/drive/MyDrive/openneuro/ds000001/deri...
# 1              True  /content/drive/MyDrive/openneuro/ds000001/deri...
# 2              True  /content/drive/MyDrive/openneuro/ds000001/deri...
# 3              True  /content/drive/MyDrive/openneuro/ds000001/deri...
# 4              True  /content/drive/MyDrive/openneuro/ds000001/deri...
# 5              True  /content/drive/MyDrive/openneuro/ds000001/deri...
# 6              True  /content/drive/MyDrive/openneuro/ds000001/deri...
# 7              True  /content/drive/MyDrive/openneuro/ds000001/deri...
# 8              True  /content/drive/MyDrive/openneuro/ds000001/deri...
# 9              True  /content/drive/MyDrive/openneuro/ds000001/deri...
# 10             True  /content/drive/MyDrive/openneuro/ds000001/deri...
# 11             True  /content/drive/MyDrive/openneuro/ds000001/deri...
# 12             True  /content/drive/MyDrive/openneuro/ds000001/deri...
# 13             True  /content/drive/MyDrive/openneuro/ds000001/deri...
# 14             True  /content/drive/MyDrive/openneuro/ds000001/deri...
# 15             True  /content/drive/MyDrive/openneuro/ds000001/deri...
#
#                                         mask_filepath  \
# 0   /content/drive/MyDrive/openneuro/ds000001/deri...
# 1   /content/drive/MyDrive/openneuro/ds000001/deri...
# 2   /content/drive/MyDrive/openneuro/ds000001/deri...
# 3   /content/drive/MyDrive/openneuro/ds000001/deri...
# 4   /content/drive/MyDrive/openneuro/ds000001/deri...
# 5   /content/drive/MyDrive/openneuro/ds000001/deri...
# 6   /content/drive/MyDrive/openneuro/ds000001/deri...
# 7   /content/drive/MyDrive/openneuro/ds000001/deri...
# 8   /content/drive/MyDrive/openneuro/ds000001/deri...
# 9   /content/drive/MyDrive/openneuro/ds000001/deri...
# 10  /content/drive/MyDrive/openneuro/ds000001/deri...
# 11  /content/drive/MyDrive/openneuro/ds000001/deri...
# 12  /content/drive/MyDrive/openneuro/ds000001/deri...
# 13  /content/drive/MyDrive/openneuro/ds000001/deri...
# 14  /content/drive/MyDrive/openneuro/ds000001/deri...
# 15  /content/drive/MyDrive/openneuro/ds000001/deri...
#
#                                       minmax_filepath  \
# 0   /content/drive/MyDrive/openneuro/ds000001/deri...
# 1   /content/drive/MyDrive/openneuro/ds000001/deri...
# 2   /content/drive/MyDrive/openneuro/ds000001/deri...
# 3   /content/drive/MyDrive/openneuro/ds000001/deri...
# 4   /content/drive/MyDrive/openneuro/ds000001/deri...
# 5   /content/drive/MyDrive/openneuro/ds000001/deri...
# 6   /content/drive/MyDrive/openneuro/ds000001/deri...
# 7   /content/drive/MyDrive/openneuro/ds000001/deri...
# 8   /content/drive/MyDrive/openneuro/ds000001/deri...
# 9   /content/drive/MyDrive/openneuro/ds000001/deri...
# 10  /content/drive/MyDrive/openneuro/ds000001/deri...
# 11  /content/drive/MyDrive/openneuro/ds000001/deri...
# 12  /content/drive/MyDrive/openneuro/ds000001/deri...
# 13  /content/drive/MyDrive/openneuro/ds000001/deri...
# 14  /content/drive/MyDrive/openneuro/ds000001/deri...
# 15  /content/drive/MyDrive/openneuro/ds000001/deri...
#
#                                       zscore_filepath
# 0   /content/drive/MyDrive/openneuro/ds000001/deri...
# 1   /content/drive/MyDrive/openneuro/ds000001/deri...
# 2   /content/drive/MyDrive/openneuro/ds000001/deri...
# 3   /content/drive/MyDrive/openneuro/ds000001/deri...
# 4   /content/drive/MyDrive/openneuro/ds000001/deri...
# 5   /content/drive/MyDrive/openneuro/ds000001/deri...
# 6   /content/drive/MyDrive/openneuro/ds000001/deri...
# 7   /content/drive/MyDrive/openneuro/ds000001/deri...
# 8   /content/drive/MyDrive/openneuro/ds000001/deri...
# 9   /content/drive/MyDrive/openneuro/ds000001/deri...
# 10  /content/drive/MyDrive/openneuro/ds000001/deri...
# 11  /content/drive/MyDrive/openneuro/ds000001/deri...
# 12  /content/drive/MyDrive/openneuro/ds000001/deri...
# 13  /content/drive/MyDrive/openneuro/ds000001/deri...
# 14  /content/drive/MyDrive/openneuro/ds000001/deri...
# 15  /content/drive/MyDrive/openneuro/ds000001/deri...

# %% [markdown]
# 3. Save the DataFrame to "drive/MyDrive/openneuro/dataframe_after_preprocessing.csv"

# %%
df.to_csv('drive/MyDrive/openneuro/dataframe_after_preprocessing.csv', index=False)

# %% [markdown]
# 4. For each Nifti in the `brain_filepath` column apply Min-max and Z-score normalization and save it to the corresponding `brain_minmax_filepath` / `brain_zscore_filepath` output *path*.

# %%
def min_max_normalize(x):
  x_min = x.min()
  x_max = x.max()
  return (x - x_min) / (x_max - x_min)

def z_score_normalize(x):
  mu = x.mean()
  std = x.std()
  return (x - mu) / std

# %%
import nibabel as nib

for in_fp, mm_fp, zs_fp in zip(df.brain_filepath, df.minmax_filepath, df.zscore_filepath):
  img = nib.load(in_fp)
  x = img.get_fdata()
  x_minmax = min_max_normalize(x)
  x_zscore = z_score_normalize(x)
  img_minmax = nib.Nifti1Image(x_minmax, img.affine, img.header)
  img_zscore = nib.Nifti1Image(x_zscore, img.affine, img.header)
  img_minmax.to_filename(mm_fp)
  img_zscore.to_filename(zs_fp)
